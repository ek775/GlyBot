# %%
import pandas as pd

# %%
curated_df = pd.read_csv('ragas_curated.csv')
synthetic_df = pd.read_csv('ragas_synth.csv')

# %%
curated_df.head()
# Out:
#    Unnamed: 0                                           question  \
# 0           0  Complete the following paragraph: A more compl...
# 1           1  Complete the following paragraph: Monosacchari...
# 2           2  Complete the following paragraph: In solution,...
# 3           3  Complete the following paragraph: After more t...
# 4           4  Complete the following paragraph: In eukaryoti...
#
#                                             contexts  \
# 0  ['When Will Glycobiology Completely Merge into...
# 1  ['The gel is then stained with Coomassie Brill...
# 2  ['The gel is then stained with Coomassie Brill...
# 3  ['When Will Glycobiology Completely Merge into...
# 4  ['Dolichol-P serves an analogous function in e...
#
#                                               answer  \
# 0  As we continue to unravel the intricacies of m...
# 1  Arabinose (Ara), Glucuronic acid (GlcA), and I...
# 2  The presence of IdoA2S and IdoA residues in a ...
# ...

# %%
curated_df.describe()
# Out:
#        Unnamed: 0  faithfulness  answer_relevancy  context_precision  \
# count   60.000000     51.000000         53.000000          60.000000
# mean    29.500000      0.332039          0.552773           0.594537
# std     17.464249      0.352952          0.148825           0.291055
# min      0.000000      0.000000          0.000000           0.000000
# 25%     14.750000      0.000000          0.552100           0.333333
# 50%     29.500000      0.250000          0.571800           0.631250
# 75%     44.250000      0.651515          0.606324           0.804514
# max     59.000000      1.000000          0.810412           1.000000
#
#        context_recall  harmfulness
# count       48.000000    52.000000
# mean         0.366089     0.942308
# std          0.361482     0.235435
# min          0.000000     0.000000
# 25%          0.000000     1.000000
# 50%          0.238636     1.000000
# 75%          0.666667     1.000000
# max          1.000000     1.000000

# %%
synthetic_df.head()
# Out:
#    Unnamed: 0                                           question  \
# 0           0  Here is a potential question that can be fully...
# 1           1  Here is a potential question that can be fully...
# 2           2  Here's a potential question based on the given...
# 3           3  Here is a potential question that can be fully...
# 4           4  Based on the context, here's a question that c...
#
#                                             contexts  \
# 0  ['Many of these claims are based on incomplete...
# 1  ['When Will Glycobiology Completely Merge into...
# 2  ['When Will Glycobiology Completely Merge into...
# 3  ['Many of these claims are based on incomplete...
# 4  ['When Will Glycobiology Completely Merge into...
#
#                                               answer  \
# 0  Based on the provided context, TREX1 plays a c...
# 1  There is no mention of Caenorhabditis elegans ...
# 2  The context information does not provide any i...
# ...

# %%
synthetic_df.describe()
# Out:
#        Unnamed: 0  faithfulness  answer_relevancy  context_precision  \
# count   16.000000     16.000000         16.000000          16.000000
# mean     7.500000      0.144296          0.313079           0.296181
# std      4.760952      0.199789          0.265068           0.372892
# min      0.000000      0.000000          0.000000           0.000000
# 25%      3.750000      0.000000          0.000000           0.000000
# 50%      7.500000      0.000000          0.432703           0.100000
# 75%     11.250000      0.262500          0.475586           0.522222
# max     15.000000      0.600000          0.799450           1.000000
#
#        context_recall  harmfulness
# count       14.000000    16.000000
# mean         0.466667     0.562500
# std          0.464280     0.512348
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          0.416667     1.000000
# 75%          1.000000     1.000000
# max          1.000000     1.000000

# %%
def sample_qs():
    import numpy as np
    select = np.random.randint(0,14,(3,1))
    for i in select:
        print("-----------------synthetic-----------------")
        print("question: " + synthetic_df.iloc[i]['question'])
        print("answer: " + synthetic_df.iloc[i]['answer'])
        print("context: " + synthetic_df.iloc[i]['contexts'])
        print("-----------------curated-----------------")
        print("question: " + curated_df.iloc[i]['question'])
        print("answer: " + curated_df.iloc[i]['answer'])
        print("context: " + curated_df.iloc[i]['contexts'])

sample_qs()
# Out:
# -----------------synthetic-----------------
# 3    question: Here is a potential question that ca...
# Name: question, dtype: object
# 3    answer: The factors that contribute to the lim...
# Name: answer, dtype: object
# 3    context: ['Many of these claims are based on i...
# Name: contexts, dtype: object
# -----------------curated-----------------
# 3    question: Complete the following paragraph: Af...
# Name: question, dtype: object
# 3    answer: As a result of this selection pressure...
# Name: answer, dtype: object
# 3    context: ['When Will Glycobiology Completely M...
# Name: contexts, dtype: object
# -----------------synthetic-----------------
# 9    question: What is the mechanism by which some ...
# Name: question, dtype: object
# 9    answer: Based on the context information provi...
# Name: answer, dtype: object
# 9    context: ['NCBI Bookshelf. A service of the Na...
# Name: contexts, dtype: object
# -----------------curated-----------------
# ...
